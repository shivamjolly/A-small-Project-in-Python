# %% [markdown]
#  Hi, this is a small project I thought of working as a way to train my skills in data visualization through Python.
#
#  I have taken a dataset which tells us about deaths caused by air pollution in different countries in the year of 2016.
#  Due to air pollution, people developed different types of deseases which caused their deaths.

# %%
# Uploading the data
import pandas as pd
data = pd.read_csv('E:\\edubridge\\datasets\\dataset.csv', header = 0)

# %%
# Showing the data
data
# Out:
#          Location                                   Dim2  \
# 0     Afghanistan                                  Total
# 1     Afghanistan                                  Total
# 2     Afghanistan                                  Total
# 3     Afghanistan                                  Total
# 4     Afghanistan                                  Total
# ...           ...                                    ...
# 6583     Zimbabwe  Chronic obstructive pulmonary disease
# 6584     Zimbabwe  Chronic obstructive pulmonary disease
# 6585     Zimbabwe  Chronic obstructive pulmonary disease
# 6586     Zimbabwe  Chronic obstructive pulmonary disease
# 6587     Zimbabwe  Chronic obstructive pulmonary disease
#
#                                               Indicator  Period        Dim1  \
# 0     Ambient and household air pollution attributab...    2016  Both sexes
# 1     Ambient and household air pollution attributab...    2016        Male
# ...

# %%
# Finding the dimensions
data.shape
# Out:
# (6588, 6)

# %%
# finding the data types of data
data.dtypes
# Out:
# Location         object
# Dim2             object
# Indicator        object
# Period            int64
# Dim1             object
# First Tooltip    object
# dtype: object

# %%
# Finding the row with maximum death rate 
data.max()
# Out:
# Location                                                  Zimbabwe
# Dim2                               Trachea, bronchus, lung cancers
# Indicator        Ambient and household air pollution attributab...
# Period                                                        2016
# Dim1                                                          Male
# First Tooltip                                  99.91 [82.73-115.4]
# dtype: object

# %%
# Changing the name of the columns
data = data.rename(columns = {'Dim2':'Diseases','Dim1':'Gender','First Tooltip':'Death rate'})
data
# Out:
#          Location                               Diseases  \
# 0     Afghanistan                                  Total
# 1     Afghanistan                                  Total
# 2     Afghanistan                                  Total
# 3     Afghanistan                                  Total
# 4     Afghanistan                                  Total
# ...           ...                                    ...
# 6583     Zimbabwe  Chronic obstructive pulmonary disease
# 6584     Zimbabwe  Chronic obstructive pulmonary disease
# 6585     Zimbabwe  Chronic obstructive pulmonary disease
# 6586     Zimbabwe  Chronic obstructive pulmonary disease
# 6587     Zimbabwe  Chronic obstructive pulmonary disease
#
#                                               Indicator  Period      Gender  \
# 0     Ambient and household air pollution attributab...    2016  Both sexes
# 1     Ambient and household air pollution attributab...    2016        Male
# ...

# %%
# Finding the mode of data
data.mode()
# Out:
#                                Location  \
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                                Angola
# 4                   Antigua and Barbuda
# ..                                  ...
# 178  Venezuela (Bolivarian Republic of)
# 179                            Viet Nam
# 180                               Yemen
# 181                              Zambia
# 182                            Zimbabwe
#
#                                   Diseases  \
# 0    Chronic obstructive pulmonary disease
# 1                  Ischaemic heart disease
# 2             Lower respiratory infections
# 3                                   Stroke
# 4                                    Total
# ..                                     ...
# 178                                    NaN
# 179                                    NaN
# 180                                    NaN
# ...

# %%
data.median()
# Out:
# Period    2016.0
# dtype: float64

# %% [markdown]
# # Visualization using different methods

# %%
# Count of countries for first 100 rows
import matplotlib.pyplot as plt
plt.hist(data['Location'].head(100))
plt.xlabel('Location')
plt.ylabel('Frequency')
plt.title('Count of every country')
# Out:
# Text(0.5, 1.0, 'Count of every country')

# %%
# Showing the count of every disease through bar graph
data['Diseases'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>
